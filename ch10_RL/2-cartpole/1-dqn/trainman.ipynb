# %%
import os
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomUniform


# 상태가 입력, 큐함수가 출력인 인공신경망 생성
class DQN(tf.keras.Model):
    def __init__(self, action_size):
        super(DQN, self).__init__()
        self.fc1 = Dense(24, activation='relu')
        self.fc2 = Dense(24, activation='relu')
        self.fc_out = Dense(action_size,
                            kernel_initializer=RandomUniform(-1e-3, 1e-3))

    def call(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        q = self.fc_out(x)
        return q


# 카트폴 예제에서의 DQN 에이전트
class DQNAgent:
    def __init__(self, state_size, action_size):
##        self.render = False
        self.render = True
        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = DQN(action_size)
        self.target_model = DQN(action_size)
        self.optimizer = Adam(lr=self.learning_rate)

        # 타깃 모델 초기화
        self.update_target_model()

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model(state)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.array([sample[0][0] for sample in mini_batch])
        actions = np.array([sample[1] for sample in mini_batch])
        rewards = np.array([sample[2] for sample in mini_batch])
        next_states = np.array([sample[3][0] for sample in mini_batch])
        dones = np.array([sample[4] for sample in mini_batch])

        # 학습 파라메터
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            # 현재 상태에 대한 모델의 큐함수
            predicts = self.model(states)
            one_hot_action = tf.one_hot(actions, self.action_size)
            predicts = tf.reduce_sum(one_hot_action * predicts, axis=1)

            # 다음 상태에 대한 타깃 모델의 큐함수
            target_predicts = self.target_model(next_states)
            target_predicts = tf.stop_gradient(target_predicts)

            # 벨만 최적 방정식을 이용한 업데이트 타깃
            max_q = np.amax(target_predicts, axis=-1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q
            loss = tf.reduce_mean(tf.square(targets - predicts))

        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))


if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # DQN 에이전트 생성
    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []
    score_avg = 0

    num_episode = 300
    for e in range(num_episode):
        done = False
        score = 0
        # env 초기화
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # 현재 상태로 행동을 선택
            action = agent.get_action(state)
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            # 타임스텝마다 보상 0.1, 에피소드가 중간에 끝나면 -1 보상
            score += reward
            reward = 0.1 if not done or score == 500 else -1

            # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
            agent.append_sample(state, action, reward, next_state, done)
            # 매 타임스텝마다 학습
            if len(agent.memory) >= agent.train_start:
                agent.train_model()

            state = next_state

            if done:
                # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
                agent.update_target_model()
                # 에피소드마다 학습 결과 출력
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print("episode: {:3d} | score avg: {:3.2f} | memory length: {:4d} | epsilon: {:.4f}".format(
                      e, score_avg, len(agent.memory), agent.epsilon))

                # 에피소드마다 학습 결과 그래프로 저장
                scores.append(score_avg)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.xlabel("episode")
                pylab.ylabel("average score")
                pylab.savefig("./save_graph/graph.png")

                # 이동 평균이 400 이상일 때 종료
                if score_avg > 400:
                    agent.model.save_weights("./save_model/model", save_format="tf")
                    sys.exit()
# Out:
# Metal device set to: Apple M1 Pro
# 2022-11-23 17:39:01.821312: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 17:39:01.821434: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# episode:   0 | score avg: 43.00 | memory length:   43 | epsilon: 1.0000
# episode:   1 | score avg: 41.00 | memory length:   66 | epsilon: 1.0000
# episode:   2 | score avg: 38.90 | memory length:   86 | epsilon: 1.0000
# episode:   3 | score avg: 36.81 | memory length:  104 | epsilon: 1.0000
# episode:   4 | score avg: 35.03 | memory length:  123 | epsilon: 1.0000
# episode:   5 | score avg: 35.43 | memory length:  162 | epsilon: 1.0000
# episode:   6 | score avg: 34.78 | memory length:  191 | epsilon: 1.0000
# episode:   7 | score avg: 33.41 | memory length:  212 | epsilon: 1.0000
# episode:   8 | score avg: 31.46 | memory length:  226 | epsilon: 1.0000
# episode:   9 | score avg: 29.32 | memory length:  236 | epsilon: 1.0000
# episode:  10 | score avg: 27.59 | memory length:  248 | epsilon: 1.0000
# episode:  11 | score avg: 27.63 | memory length:  276 | epsilon: 1.0000
# episode:  12 | score avg: 25.96 | memory length:  287 | epsilon: 1.0000
# episode:  13 | score avg: 25.07 | memory length:  304 | epsilon: 1.0000
# episode:  14 | score avg: 24.06 | memory length:  319 | epsilon: 1.0000
# episode:  15 | score avg: 22.86 | memory length:  331 | epsilon: 1.0000
# episode:  16 | score avg: 22.47 | memory length:  350 | epsilon: 1.0000
# episode:  17 | score avg: 21.82 | memory length:  366 | epsilon: 1.0000
# episode:  18 | score avg: 20.84 | memory length:  378 | epsilon: 1.0000
# episode:  19 | score avg: 20.16 | memory length:  392 | epsilon: 1.0000
# episode:  20 | score avg: 22.24 | memory length:  433 | epsilon: 1.0000
# episode:  21 | score avg: 21.42 | memory length:  447 | epsilon: 1.0000
# episode:  22 | score avg: 22.58 | memory length:  480 | epsilon: 1.0000
# episode:  23 | score avg: 22.42 | memory length:  501 | epsilon: 1.0000
# episode:  24 | score avg: 24.08 | memory length:  540 | epsilon: 1.0000
# episode:  25 | score avg: 22.57 | memory length:  549 | epsilon: 1.0000
# episode:  26 | score avg: 21.71 | memory length:  563 | epsilon: 1.0000
# episode:  27 | score avg: 21.84 | memory length:  586 | epsilon: 1.0000
# episode:  28 | score avg: 21.46 | memory length:  604 | epsilon: 1.0000
# episode:  29 | score avg: 21.31 | memory length:  624 | epsilon: 1.0000
# episode:  30 | score avg: 25.38 | memory length:  686 | epsilon: 1.0000
# episode:  31 | score avg: 23.84 | memory length:  696 | epsilon: 1.0000
# episode:  32 | score avg: 24.56 | memory length:  727 | epsilon: 1.0000
# episode:  33 | score avg: 23.90 | memory length:  745 | epsilon: 1.0000
# episode:  34 | score avg: 22.41 | memory length:  754 | epsilon: 1.0000
# episode:  35 | score avg: 21.47 | memory length:  767 | epsilon: 1.0000
# episode:  36 | score avg: 21.12 | memory length:  785 | epsilon: 1.0000
# episode:  37 | score avg: 20.71 | memory length:  802 | epsilon: 1.0000
# episode:  38 | score avg: 20.94 | memory length:  825 | epsilon: 1.0000
# episode:  39 | score avg: 20.25 | memory length:  839 | epsilon: 1.0000
# episode:  40 | score avg: 20.12 | memory length:  858 | epsilon: 1.0000
# episode:  41 | score avg: 19.21 | memory length:  869 | epsilon: 1.0000
# episode:  42 | score avg: 18.69 | memory length:  883 | epsilon: 1.0000
# episode:  43 | score avg: 20.12 | memory length:  916 | epsilon: 1.0000
# episode:  44 | score avg: 20.11 | memory length:  936 | epsilon: 1.0000
# episode:  45 | score avg: 22.40 | memory length:  979 | epsilon: 1.0000
# episode:  46 | score avg: 22.16 | memory length:  999 | epsilon: 1.0000
# episode:  47 | score avg: 21.54 | memory length: 1015 | epsilon: 0.9841
# episode:  48 | score avg: 22.59 | memory length: 1047 | epsilon: 0.9531
# episode:  49 | score avg: 21.63 | memory length: 1060 | epsilon: 0.9408
# episode:  50 | score avg: 20.67 | memory length: 1072 | epsilon: 0.9296
# episode:  51 | score avg: 19.90 | memory length: 1085 | epsilon: 0.9176
# episode: 205 | score avg: 291.25 | memory length: 2000 | epsilon: 0.0100
# episode: 206 | score avg: 296.42 | memory length: 2000 | epsilon: 0.0100
# episode: 207 | score avg: 313.88 | memory length: 2000 | epsilon: 0.0100
# episode: 208 | score avg: 332.49 | memory length: 2000 | epsilon: 0.0100
# episode: 209 | score avg: 339.84 | memory length: 2000 | epsilon: 0.0100
# episode: 210 | score avg: 340.06 | memory length: 2000 | epsilon: 0.0100
# episode: 211 | score avg: 325.45 | memory length: 2000 | epsilon: 0.0100
# episode: 212 | score avg: 309.61 | memory length: 2000 | epsilon: 0.0100
# episode: 213 | score avg: 280.95 | memory length: 2000 | epsilon: 0.0100
# episode: 214 | score avg: 261.05 | memory length: 2000 | epsilon: 0.0100
# episode: 215 | score avg: 242.65 | memory length: 2000 | epsilon: 0.0100
# episode: 216 | score avg: 268.38 | memory length: 2000 | epsilon: 0.0100
# episode: 217 | score avg: 291.54 | memory length: 2000 | epsilon: 0.0100
# episode: 218 | score avg: 308.29 | memory length: 2000 | epsilon: 0.0100
# episode: 219 | score avg: 327.46 | memory length: 2000 | epsilon: 0.0100
# episode: 220 | score avg: 344.72 | memory length: 2000 | epsilon: 0.0100
# episode: 221 | score avg: 360.24 | memory length: 2000 | epsilon: 0.0100
# episode: 222 | score avg: 351.22 | memory length: 2000 | epsilon: 0.0100
# episode: 223 | score avg: 339.50 | memory length: 2000 | epsilon: 0.0100
# episode: 224 | score avg: 328.45 | memory length: 2000 | epsilon: 0.0100
# episode: 225 | score avg: 315.00 | memory length: 2000 | epsilon: 0.0100
# episode: 226 | score avg: 304.60 | memory length: 2000 | epsilon: 0.0100
# episode: 227 | score avg: 295.94 | memory length: 2000 | epsilon: 0.0100
# episode: 228 | score avg: 282.95 | memory length: 2000 | epsilon: 0.0100
# episode: 229 | score avg: 273.95 | memory length: 2000 | epsilon: 0.0100
# episode: 230 | score avg: 268.46 | memory length: 2000 | epsilon: 0.0100
# episode: 231 | score avg: 260.81 | memory length: 2000 | epsilon: 0.0100
# episode: 232 | score avg: 255.73 | memory length: 2000 | epsilon: 0.0100
# episode: 233 | score avg: 248.76 | memory length: 2000 | epsilon: 0.0100
# episode: 234 | score avg: 243.48 | memory length: 2000 | epsilon: 0.0100
# episode: 235 | score avg: 240.03 | memory length: 2000 | epsilon: 0.0100
# episode: 236 | score avg: 238.73 | memory length: 2000 | epsilon: 0.0100
# episode: 237 | score avg: 242.66 | memory length: 2000 | epsilon: 0.0100
# episode: 238 | score avg: 248.69 | memory length: 2000 | epsilon: 0.0100
# episode: 239 | score avg: 263.02 | memory length: 2000 | epsilon: 0.0100
# episode: 240 | score avg: 282.52 | memory length: 2000 | epsilon: 0.0100
# episode: 241 | score avg: 304.27 | memory length: 2000 | epsilon: 0.0100
# episode: 242 | score avg: 323.84 | memory length: 2000 | epsilon: 0.0100
# episode: 243 | score avg: 325.66 | memory length: 2000 | epsilon: 0.0100
# episode: 244 | score avg: 302.19 | memory length: 2000 | epsilon: 0.0100
# episode: 245 | score avg: 289.97 | memory length: 2000 | epsilon: 0.0100
# episode: 246 | score avg: 271.48 | memory length: 2000 | epsilon: 0.0100
# episode: 247 | score avg: 294.33 | memory length: 2000 | epsilon: 0.0100
# episode: 248 | score avg: 296.99 | memory length: 2000 | epsilon: 0.0100
# episode: 249 | score avg: 317.30 | memory length: 2000 | epsilon: 0.0100
# episode: 250 | score avg: 314.17 | memory length: 2000 | epsilon: 0.0100
# episode: 251 | score avg: 323.35 | memory length: 2000 | epsilon: 0.0100
# episode: 252 | score avg: 333.71 | memory length: 2000 | epsilon: 0.0100
# episode: 253 | score avg: 330.44 | memory length: 2000 | epsilon: 0.0100
# episode: 254 | score avg: 347.40 | memory length: 2000 | epsilon: 0.0100
# episode: 255 | score avg: 350.86 | memory length: 2000 | epsilon: 0.0100
# episode: 256 | score avg: 317.57 | memory length: 2000 | epsilon: 0.0100
# episode: 257 | score avg: 289.12 | memory length: 2000 | epsilon: 0.0100
# episode: 258 | score avg: 262.80 | memory length: 2000 | epsilon: 0.0100
# episode: 259 | score avg: 240.62 | memory length: 2000 | epsilon: 0.0100
# episode: 260 | score avg: 220.46 | memory length: 2000 | epsilon: 0.0100
# episode: 261 | score avg: 202.82 | memory length: 2000 | epsilon: 0.0100
# episode: 262 | score avg: 186.83 | memory length: 2000 | epsilon: 0.0100
# episode: 263 | score avg: 171.55 | memory length: 2000 | epsilon: 0.0100
# episode: 264 | score avg: 159.70 | memory length: 2000 | epsilon: 0.0100
# episode: 265 | score avg: 159.13 | memory length: 2000 | epsilon: 0.0100
# episode: 266 | score avg: 149.81 | memory length: 2000 | epsilon: 0.0100
# episode: 267 | score avg: 143.33 | memory length: 2000 | epsilon: 0.0100
# episode: 268 | score avg: 136.20 | memory length: 2000 | epsilon: 0.0100
# episode: 269 | score avg: 172.58 | memory length: 2000 | epsilon: 0.0100
# episode: 270 | score avg: 199.32 | memory length: 2000 | epsilon: 0.0100
# episode: 271 | score avg: 197.59 | memory length: 2000 | epsilon: 0.0100
# episode: 272 | score avg: 193.43 | memory length: 2000 | epsilon: 0.0100
# episode: 273 | score avg: 188.59 | memory length: 2000 | epsilon: 0.0100
# episode: 274 | score avg: 186.13 | memory length: 2000 | epsilon: 0.0100
# episode: 275 | score avg: 185.32 | memory length: 2000 | epsilon: 0.0100
# episode: 276 | score avg: 184.88 | memory length: 2000 | epsilon: 0.0100
# episode: 277 | score avg: 188.60 | memory length: 2000 | epsilon: 0.0100
# episode: 278 | score avg: 194.34 | memory length: 2000 | epsilon: 0.0100
# episode: 279 | score avg: 192.10 | memory length: 2000 | epsilon: 0.0100
# episode: 280 | score avg: 192.59 | memory length: 2000 | epsilon: 0.0100
# episode: 281 | score avg: 199.03 | memory length: 2000 | epsilon: 0.0100
