# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# for reproducibility
np.random.seed(1671)

# network and training
EPOCHS1L = 200 ## for 1-layer
EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

DROPOUT = 0.3

# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly 
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')


#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784   #28x28 input
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
Y_train = Y_train.astype('float32')
Y_test = Y_test.astype('float32')

### 1-layer NN
##model = tf.keras.models.Sequential()
##model.add(keras.layers.Dense(NB_CLASSES,input_shape=(RESHAPED,),name='dense_layer', activation='softmax'))


### multi-layer NN
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,input_shape=(RESHAPED,),name='dense_layer', activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN,name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES,name='dense_layer_3', activation='softmax'))

### multi-layer NN with DROPOUT
#model = tf.keras.models.Sequential()
#model.add(keras.layers.Dense(N_HIDDEN,input_shape=(RESHAPED,),name='dense_layer', activation='relu'))
#model.add(keras.layers.Dropout(DROPOUT))
#model.add(keras.layers.Dense(N_HIDDEN,name='dense_layer_2', activation='relu'))
#model.add(keras.layers.Dropout(DROPOUT))
#model.add(keras.layers.Dense(NB_CLASSES,name='dense_layer_3', activation='softmax'))


# summary of the model
model.summary()

# compiling the model SGM 1st try
#model.compile(optimizer='SGD', 
#              loss='sparse_categorical_crossentropy',
#              metrics=['accuracy'])

# compiling the model RMSProp 2nd try
#model.compile(optimizer='RMSProp', 
#              loss='sparse_categorical_crossentropy',
#              metrics=['accuracy'])

# compiling the model Adam 3rd try
model.compile(optimizer='Adam', 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

#training the moodel with Singlelayer P
#model.fit(X_train, Y_train,
#		batch_size=BATCH_SIZE, epochs=EPOCHS1L,
#		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

#training the moodel with Multilayer P
model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

#evalute the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

# making prediction
predictions = model.predict(X_test)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer (Dense)         (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dense_layer_3 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  10/375 [..............................] - ETA: 2s - loss: 1.9651 - accuracy: 0.4172
# 2022-09-14 13:16:30.465584: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 370/375 [============================>.] - ETA: 0s - loss: 0.3588 - accuracy: 0.8983
# 2022-09-14 13:16:32.268072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3564 - accuracy: 0.8989 - val_loss: 0.1762 - val_accuracy: 0.9492
# Epoch 2/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1535 - accuracy: 0.9553 - val_loss: 0.1328 - val_accuracy: 0.9604
# Epoch 3/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1054 - accuracy: 0.9691 - val_loss: 0.1160 - val_accuracy: 0.9658
# Epoch 4/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0774 - accuracy: 0.9772 - val_loss: 0.0939 - val_accuracy: 0.9707
# Epoch 5/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0602 - accuracy: 0.9821 - val_loss: 0.1059 - val_accuracy: 0.9682
# Epoch 6/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0485 - accuracy: 0.9851 - val_loss: 0.0939 - val_accuracy: 0.9707
# Epoch 7/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0391 - accuracy: 0.9877 - val_loss: 0.0939 - val_accuracy: 0.9737
# Epoch 8/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0318 - accuracy: 0.9900 - val_loss: 0.0902 - val_accuracy: 0.9743
# Epoch 9/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.1013 - val_accuracy: 0.9722
# Epoch 10/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0229 - accuracy: 0.9929 - val_loss: 0.0958 - val_accuracy: 0.9743
# Epoch 11/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.1034 - val_accuracy: 0.9733
# Epoch 12/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 0.0980 - val_accuracy: 0.9736
# Epoch 13/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.0973 - val_accuracy: 0.9752
# Epoch 14/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.1160 - val_accuracy: 0.9731
# Epoch 15/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.1021 - val_accuracy: 0.9771
# Epoch 16/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.1135 - val_accuracy: 0.9744
# Epoch 17/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.1206 - val_accuracy: 0.9733
# Epoch 18/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.1459 - val_accuracy: 0.9702
# Epoch 19/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.1246 - val_accuracy: 0.9729
# Epoch 20/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.1201 - val_accuracy: 0.9771
# Epoch 21/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1219 - val_accuracy: 0.9763
# Epoch 22/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.1325 - val_accuracy: 0.9747
# Epoch 23/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.1215 - val_accuracy: 0.9758
# Epoch 24/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.1322 - val_accuracy: 0.9762
# Epoch 25/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.1235 - val_accuracy: 0.9763
# Epoch 26/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1258 - val_accuracy: 0.9778
# Epoch 27/50
# 375/375 [==============================] - 2s 5ms/step - loss: 8.8652e-04 - accuracy: 0.9999 - val_loss: 0.1225 - val_accuracy: 0.9787
# Epoch 28/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 0.1414 - val_accuracy: 0.9738
# Epoch 29/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.1495 - val_accuracy: 0.9740
# Epoch 30/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.1230 - val_accuracy: 0.9772
# Epoch 31/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.1242 - val_accuracy: 0.9786
# Epoch 32/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1211 - val_accuracy: 0.9804
# Epoch 33/50
# 375/375 [==============================] - 2s 5ms/step - loss: 3.6839e-04 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9808
# Epoch 34/50
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0863e-04 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9812
# Epoch 35/50
# 375/375 [==============================] - 2s 5ms/step - loss: 7.4906e-05 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9811
# Epoch 36/50
# 375/375 [==============================] - 2s 5ms/step - loss: 6.1507e-05 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9810
# Epoch 37/50
# 375/375 [==============================] - 2s 5ms/step - loss: 5.2591e-05 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9812
# Epoch 38/50
# 375/375 [==============================] - 2s 5ms/step - loss: 4.4831e-05 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 0.9809
# Epoch 39/50
# 375/375 [==============================] - 2s 5ms/step - loss: 3.8342e-05 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9812
# Epoch 40/50
# 375/375 [==============================] - 2s 5ms/step - loss: 3.3991e-05 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9809
# Epoch 41/50
# 159/375 [===========>..................] - ETA: 0s - loss: 2.9432e-05 - accuracy: 1.0000
