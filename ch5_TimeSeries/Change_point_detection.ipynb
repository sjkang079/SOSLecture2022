# %%
# !pip install ruptures
# Out:
# Collecting ruptures
#   Using cached ruptures-1.1.7.tar.gz (241 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy in /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ruptures) (1.8.0)
# Requirement already satisfied: numpy in /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from ruptures) (1.21.5)
# Building wheels for collected packages: ruptures
#   Building wheel for ruptures (pyproject.toml) ... done
#   Created wheel for ruptures: filename=ruptures-1.1.7-cp39-cp39-macosx_11_0_arm64.whl size=380512 sha256=fc4e67303afa34341905f23fbd00b4999741bd27494960c27199fc79e8ad8a9a
#   Stored in directory: /Users/sjkang/Library/Caches/pip/wheels/fa/70/b9/5c0b2bc1f27a566dad0b0b45d9412475e47793b693b8f09c07
# Successfully built ruptures
# Installing collected packages: ruptures
# Successfully installed ruptures-1.1.7

# %%
import matplotlib.pyplot as plt
import numpy as np
import ruptures as rpt

plt.style.use("seaborn-whitegrid")
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "17"

# %%
signal, bkps = rpt.pw_constant(
    n_samples=500, n_features=3, n_bkps=2, noise_std=5.0, delta=(1, 20)
)

# %%
rpt.display(signal, bkps)
# Out:
# (<Figure size 720x432 with 3 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
signal.shape
# Out:
# (500, 3)

# %%
bkps
# Out:
# [176, 338, 500]

# %%
# "l1", "rbf", "linear", "normal", "ar"
algo = rpt.Binseg(model="l1").fit(signal)
my_bkps = algo.predict(n_bkps=3)

# show results
rpt.show.display(signal, bkps, my_bkps, figsize=(10, 6))
# Out:
# (<Figure size 720x432 with 3 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object))
