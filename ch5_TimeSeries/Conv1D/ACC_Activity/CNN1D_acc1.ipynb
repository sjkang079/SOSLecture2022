# %%
# !pip install coremltools
# Out:
# Collecting coremltools
#   Downloading coremltools-5.2.0-cp39-none-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm in /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from coremltools) (4.63.0)
# Requirement already satisfied: protobuf>=3.1.0 in /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from coremltools) (3.19.4)
# Requirement already satisfied: packaging in /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from coremltools) (21.3)
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 4.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.14.5 in /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from coremltools) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sjkang/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from packaging->coremltools) (3.0.7)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.6/532.6 kB 4.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mpmath, sympy, coremltools
# Successfully installed coremltools-5.2.0 mpmath-1.2.1 sympy-1.11.1
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
from __future__ import print_function
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import coremltools
from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
# Out:
# WARNING:root:scikit-learn version 1.0.2 is not supported. Minimum required version: 0.17. Maximum required version: 0.19.2. Disabling scikit-learn conversion API.
# WARNING:root:TensorFlow version 2.8.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.6.2 is the most recent version that has been tested.
# WARNING:root:Keras version 2.8.0 has not been tested with coremltools. You may run into unexpected errors. Keras 2.6.0 is the most recent version that has been tested.

# %%
# Set some standard parameters upfront
pd.options.display.float_format = '{:.1f}'.format
sns.set() # Default seaborn look and feel
plt.style.use('ggplot')
print('keras version ', keras.__version__)
# Same labels will be reused throughout the program
LABELS = ['Downstairs',
          'Jogging',
          'Sitting',
          'Standing',
          'Upstairs',
          'Walking']
# The number of steps within one time segment
TIME_PERIODS = 80
# The steps to take from one segment to the next; if this value is equal to
# TIME_PERIODS, then there is no overlap between the segments
STEP_DISTANCE = 40
# Out:
# keras version  2.8.0

# %%
def read_data(file_path):

    column_names = ['user-id',
                    'activity',
                    'timestamp',
                    'x-axis',
                    'y-axis',
                    'z-axis']
    df = pd.read_csv(file_path,
                     header=None,
                     names=column_names)
    # Last column has a ";" character which must be removed ...
    df['z-axis'].replace(regex=True,
      inplace=True,
      to_replace=r';',
      value=r'')
    # ... and then this column must be transformed to float explicitly
    df['z-axis'] = df['z-axis'].apply(convert_to_float)
    # This is very important otherwise the model will not fit and loss
    # will show up as NAN
    df.dropna(axis=0, how='any', inplace=True)

    return df

def convert_to_float(x):

    try:
        return np.float(x)
    except:
        return np.nan
 
def show_basic_dataframe_info(dataframe):

    # Shape and how many rows and columns
    print('Number of columns in the dataframe: %i' % (dataframe.shape[1]))
    print('Number of rows in the dataframe: %i\n' % (dataframe.shape[0]))

# Load data set containing all the data from csv
df = read_data('./WISDM_ar_v1.1_raw.txt')
# Out:
# /var/folders/p5/32mb12x959s4wk6tf8vcdx680000gn/T/ipykernel_2799/2925378018.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.float(x)

# %%
# Describe the data
show_basic_dataframe_info(df)
df.head(20)
# Out:
# Number of columns in the dataframe: 6
# Number of rows in the dataframe: 1098203
#     user-id activity       timestamp  x-axis  y-axis  z-axis
# 0        33  Jogging  49105962326000    -0.7    12.7     0.5
# 1        33  Jogging  49106062271000     5.0    11.3     1.0
# 2        33  Jogging  49106112167000     4.9    10.9    -0.1
# 3        33  Jogging  49106222305000    -0.6    18.5     3.0
# 4        33  Jogging  49106332290000    -1.2    12.1     7.2
# 5        33  Jogging  49106442306000     1.4    -2.5    -6.5
# 6        33  Jogging  49106542312000    -0.6    10.6     5.7
# 7        33  Jogging  49106652389000    -0.5    13.9     7.1
# 8        33  Jogging  49106762313000    -8.4    11.4     5.1
# 9        33  Jogging  49106872299000     1.0     1.4     1.6
# 10       33  Jogging  49106982315000    -8.2    19.6     2.7
# 11       33  Jogging  49107092330000     1.4     5.8     3.0
# 12       33  Jogging  49107202316000    -1.9    -3.0    -0.3
# 13       33  Jogging  49107312332000    -6.1     6.9    -8.2
# 14       33  Jogging  49107422348000     5.8    18.0     8.5
# 15       33  Jogging  49107522293000     6.3     3.0     2.9
# 16       33  Jogging  49107632339000    -1.6     8.3    -1.5
# 17       33  Jogging  49107742355000     3.5    13.6     9.4
# 18       33  Jogging  49107852340000    -2.0    -5.7   -10.2
# 19       33  Jogging  49107962326000     2.8    10.3    -9.7

# %%
# Show how many training examples exist for each of the six activities
df['activity'].value_counts().plot(kind='bar',
                                   title='Training Examples by Activity Type')
plt.show()
# Better understand how the recordings are spread across the different
# users who participated in the study
df['user-id'].value_counts().plot(kind='bar',
                                  title='Training Examples by User')
plt.show()

# %%
def plot_activity(activity, data):

    fig, (ax0, ax1, ax2) = plt.subplots(nrows=3,
         figsize=(15, 10),
         sharex=True)
    plot_axis(ax0, data['timestamp'], data['x-axis'], 'X-Axis')
    plot_axis(ax1, data['timestamp'], data['y-axis'], 'Y-Axis')
    plot_axis(ax2, data['timestamp'], data['z-axis'], 'Z-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(activity)
    plt.subplots_adjust(top=0.90)
    plt.show()

def plot_axis(ax, x, y, title):

    ax.plot(x, y, 'r')
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)

for activity in np.unique(df['activity']):
    subset = df[df['activity'] == activity][:180]
    plot_activity(activity, subset)

# %%
# Define column name of the label vector
LABEL = 'ActivityEncoded'
# Transform the labels from String to Integer via LabelEncoder
le = preprocessing.LabelEncoder()
# Add a new column to the existing DataFrame with the encoded values
df[LABEL] = le.fit_transform(df['activity'].values.ravel())

df.head(20)
# Out:
#     user-id activity       timestamp  x-axis  y-axis  z-axis  ActivityEncoded
# 0        33  Jogging  49105962326000    -0.7    12.7     0.5                1
# 1        33  Jogging  49106062271000     5.0    11.3     1.0                1
# 2        33  Jogging  49106112167000     4.9    10.9    -0.1                1
# 3        33  Jogging  49106222305000    -0.6    18.5     3.0                1
# 4        33  Jogging  49106332290000    -1.2    12.1     7.2                1
# 5        33  Jogging  49106442306000     1.4    -2.5    -6.5                1
# 6        33  Jogging  49106542312000    -0.6    10.6     5.7                1
# 7        33  Jogging  49106652389000    -0.5    13.9     7.1                1
# 8        33  Jogging  49106762313000    -8.4    11.4     5.1                1
# 9        33  Jogging  49106872299000     1.0     1.4     1.6                1
# 10       33  Jogging  49106982315000    -8.2    19.6     2.7                1
# 11       33  Jogging  49107092330000     1.4     5.8     3.0                1
# 12       33  Jogging  49107202316000    -1.9    -3.0    -0.3                1
# 13       33  Jogging  49107312332000    -6.1     6.9    -8.2                1
# 14       33  Jogging  49107422348000     5.8    18.0     8.5                1
# 15       33  Jogging  49107522293000     6.3     3.0     2.9                1
# 16       33  Jogging  49107632339000    -1.6     8.3    -1.5                1
# 17       33  Jogging  49107742355000     3.5    13.6     9.4                1
# 18       33  Jogging  49107852340000    -2.0    -5.7   -10.2                1
# 19       33  Jogging  49107962326000     2.8    10.3    -9.7                1

# %%
# Differentiate between test set and training set
df_test = df[df['user-id'] > 28]
df_train = df[df['user-id'] <= 28]

# %%
# Normalize features for training data set (values between 0 and 1)
# Surpress warning for next 3 operation
pd.options.mode.chained_assignment = None  # default='warn'
df_train['x-axis'] = df_train['x-axis'] / df_train['x-axis'].max()
df_train['y-axis'] = df_train['y-axis'] / df_train['y-axis'].max()
df_train['z-axis'] = df_train['z-axis'] / df_train['z-axis'].max()
# Round numbers
df_train = df_train.round({'x-axis': 4, 'y-axis': 4, 'z-axis': 4})

# %%
def create_segments_and_labels(df, time_steps, step, label_name):

    # x, y, z acceleration as features
    N_FEATURES = 3
    # Number of steps to advance in each iteration (for me, it should always
    # be equal to the time_steps in order to have no overlap between segments)
    # step = time_steps
    segments = []
    labels = []
    for i in range(0, len(df) - time_steps, step):
        xs = df['x-axis'].values[i: i + time_steps]
        ys = df['y-axis'].values[i: i + time_steps]
        zs = df['z-axis'].values[i: i + time_steps]
        # Retrieve the most often used label in this segment
        label = stats.mode(df[label_name][i: i + time_steps])[0][0]
        segments.append([xs, ys, zs])
        labels.append(label)

    # Bring the segments into a better shape
    reshaped_segments = np.asarray(segments, dtype= np.float32).reshape(-1, time_steps, N_FEATURES)
    labels = np.asarray(labels)

    return reshaped_segments, labels

x_train, y_train = create_segments_and_labels(df_train,
                                              TIME_PERIODS,
                                              STEP_DISTANCE,
                                              LABEL)

print('x_train shape: ', x_train.shape)
print(x_train.shape[0], 'training samples')
print('y_train shape: ', y_train.shape)
# Out:
# x_train shape:  (20868, 80, 3)
# 20868 training samples
# y_train shape:  (20868,)

# %%
# Set input & output dimensions
num_time_periods, num_sensors = x_train.shape[1], x_train.shape[2]
num_classes = le.classes_.size
print(list(le.classes_))
# Out:
# ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']

# %%
input_shape = (num_time_periods*num_sensors)
x_train = x_train.reshape(x_train.shape[0], input_shape)
print('x_train shape:', x_train.shape)
print('input_shape:', input_shape)
# Out:
# x_train shape: (20868, 240)
# input_shape: 240

# %%
x_train = x_train.astype('float32')
y_train = y_train.astype('float32')
y_train_hot = np_utils.to_categorical(y_train, num_classes)
print('New y_train shape: ', y_train_hot.shape)

df.head()
# Out:
# New y_train shape:  (20868, 6)
#    user-id activity       timestamp  x-axis  y-axis  z-axis  ActivityEncoded
# 0       33  Jogging  49105962326000    -0.7    12.7     0.5                1
# 1       33  Jogging  49106062271000     5.0    11.3     1.0                1
# 2       33  Jogging  49106112167000     4.9    10.9    -0.1                1
# 3       33  Jogging  49106222305000    -0.6    18.5     3.0                1
# 4       33  Jogging  49106332290000    -1.2    12.1     7.2                1

# %%
model_m = Sequential()
# Remark: since coreml cannot accept vector shapes of complex shape like
# [80,3] this workaround is used in order to reshape the vector internally
# prior feeding it into the network
model_m.add(Reshape((TIME_PERIODS, 3), input_shape=(input_shape,)))
model_m.add(Dense(100, activation='relu'))
model_m.add(Dense(100, activation='relu'))
model_m.add(Dense(100, activation='relu'))
model_m.add(Flatten())
model_m.add(Dense(num_classes, activation='softmax'))
print(model_m.summary())
# Out:
# Metal device set to: Apple M1 Pro
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 80, 3)             0
#
#  dense (Dense)               (None, 80, 100)           400
#
#  dense_1 (Dense)             (None, 80, 100)           10100
#
#  dense_2 (Dense)             (None, 80, 100)           10100
#
#  flatten (Flatten)           (None, 8000)              0
#
#  dense_3 (Dense)             (None, 6)                 48006
#
# =================================================================
# Total params: 68,606
# Trainable params: 68,606
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    keras.callbacks.EarlyStopping(monitor='acc', patience=1)
]

model_m.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

##model_m.compile(loss='categorical_crossentropy',
##                optimizer='adam', metrics=['acc'])

# Hyper-parameters
BATCH_SIZE = 400
EPOCHS = 50

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
history = model_m.fit(x_train,
                      y_train_hot,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      callbacks=callbacks_list,
                      validation_split=0.2,
                      verbose=1)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 3s 27ms/step - loss: 1.0700 - accuracy: 0.6498 - val_loss: 0.7391 - val_accuracy: 0.7949
# Epoch 2/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6034 - accuracy: 0.7840 - val_loss: 0.7006 - val_accuracy: 0.7817
# Epoch 3/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.5255 - accuracy: 0.8101 - val_loss: 0.6350 - val_accuracy: 0.8280
# Epoch 4/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.4943 - accuracy: 0.8178 - val_loss: 0.6452 - val_accuracy: 0.8093
# Epoch 5/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.4661 - accuracy: 0.8304 - val_loss: 0.6704 - val_accuracy: 0.7961
# Epoch 6/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.4460 - accuracy: 0.8387 - val_loss: 0.6549 - val_accuracy: 0.8184
# Epoch 7/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.4312 - accuracy: 0.8430 - val_loss: 0.6715 - val_accuracy: 0.8165
# Epoch 8/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.4166 - accuracy: 0.8482 - val_loss: 0.7138 - val_accuracy: 0.7575
# Epoch 9/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.4023 - accuracy: 0.8525 - val_loss: 0.7436 - val_accuracy: 0.7432
# Epoch 10/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.3906 - accuracy: 0.8580 - val_loss: 0.7295 - val_accuracy: 0.7437
# Epoch 11/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.3790 - accuracy: 0.8627 - val_loss: 0.6956 - val_accuracy: 0.7846
# Epoch 12/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.3698 - accuracy: 0.8658 - val_loss: 0.7457 - val_accuracy: 0.7928
# Epoch 13/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.3623 - accuracy: 0.8660 - val_loss: 0.7369 - val_accuracy: 0.7786
# Epoch 14/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.3528 - accuracy: 0.8706 - val_loss: 0.7425 - val_accuracy: 0.7597
# Epoch 15/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.3381 - accuracy: 0.8766 - val_loss: 0.8124 - val_accuracy: 0.7259
# Epoch 16/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.3252 - accuracy: 0.8798 - val_loss: 0.7720 - val_accuracy: 0.7393
# Epoch 17/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.3203 - accuracy: 0.8812 - val_loss: 0.7886 - val_accuracy: 0.7379
# Epoch 18/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.3121 - accuracy: 0.8860 - val_loss: 0.8126 - val_accuracy: 0.7427
# Epoch 19/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.2962 - accuracy: 0.8907 - val_loss: 0.9024 - val_accuracy: 0.6914
# Epoch 20/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2893 - accuracy: 0.8946 - val_loss: 0.8817 - val_accuracy: 0.7094
# Epoch 21/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.2745 - accuracy: 0.9005 - val_loss: 0.8872 - val_accuracy: 0.7063
# Epoch 22/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2756 - accuracy: 0.8979 - val_loss: 0.8881 - val_accuracy: 0.7089
# Epoch 23/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.2698 - accuracy: 0.9014 - val_loss: 0.8979 - val_accuracy: 0.7103
# Epoch 24/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2574 - accuracy: 0.9048 - val_loss: 0.8754 - val_accuracy: 0.7202
# Epoch 25/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2475 - accuracy: 0.9099 - val_loss: 0.9156 - val_accuracy: 0.6926
# Epoch 26/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2437 - accuracy: 0.9112 - val_loss: 0.9267 - val_accuracy: 0.7068
# Epoch 27/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2387 - accuracy: 0.9122 - val_loss: 0.8790 - val_accuracy: 0.7566
# Epoch 28/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2346 - accuracy: 0.9113 - val_loss: 1.0704 - val_accuracy: 0.6608
# Epoch 29/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.2271 - accuracy: 0.9172 - val_loss: 0.8993 - val_accuracy: 0.7475
# Epoch 30/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2184 - accuracy: 0.9186 - val_loss: 1.0087 - val_accuracy: 0.6847
# Epoch 31/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2166 - accuracy: 0.9202 - val_loss: 0.9253 - val_accuracy: 0.7458
# Epoch 32/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2027 - accuracy: 0.9286 - val_loss: 1.0184 - val_accuracy: 0.7084
# Epoch 33/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1987 - accuracy: 0.9293 - val_loss: 1.0286 - val_accuracy: 0.6840
# Epoch 34/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.2032 - accuracy: 0.9236 - val_loss: 1.0362 - val_accuracy: 0.7123
# Epoch 35/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1960 - accuracy: 0.9281 - val_loss: 1.1079 - val_accuracy: 0.6701
# Epoch 36/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1897 - accuracy: 0.9324 - val_loss: 0.9753 - val_accuracy: 0.7226
# Epoch 37/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1921 - accuracy: 0.9316 - val_loss: 1.0767 - val_accuracy: 0.6986
# Epoch 38/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1776 - accuracy: 0.9364 - val_loss: 1.1084 - val_accuracy: 0.6869
# Epoch 39/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1755 - accuracy: 0.9384 - val_loss: 1.0972 - val_accuracy: 0.6921
# Epoch 40/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1733 - accuracy: 0.9384 - val_loss: 1.1476 - val_accuracy: 0.6876
# Epoch 41/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1721 - accuracy: 0.9392 - val_loss: 1.1248 - val_accuracy: 0.7118
# Epoch 42/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1656 - accuracy: 0.9403 - val_loss: 1.1999 - val_accuracy: 0.6845
# Epoch 43/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1582 - accuracy: 0.9428 - val_loss: 1.1070 - val_accuracy: 0.7185
# Epoch 44/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1536 - accuracy: 0.9475 - val_loss: 1.2976 - val_accuracy: 0.6529
# Epoch 45/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1533 - accuracy: 0.9461 - val_loss: 1.2988 - val_accuracy: 0.6749
# Epoch 46/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1493 - accuracy: 0.9481 - val_loss: 1.1913 - val_accuracy: 0.6993
# Epoch 47/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1471 - accuracy: 0.9484 - val_loss: 1.2821 - val_accuracy: 0.6792
# Epoch 48/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1445 - accuracy: 0.9482 - val_loss: 1.1170 - val_accuracy: 0.7233
# Epoch 49/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1417 - accuracy: 0.9511 - val_loss: 1.3952 - val_accuracy: 0.6627
# Epoch 50/50
# 42/42 [==============================] - 1s 21ms/step - loss: 0.1549 - accuracy: 0.9441 - val_loss: 1.2098 - val_accuracy: 0.7115

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], 'r', label='Accuracy of training data')
plt.plot(history.history['val_accuracy'], 'b', label='Accuracy of validation data')
plt.plot(history.history['loss'], 'r--', label='Loss of training data')
plt.plot(history.history['val_loss'], 'b--', label='Loss of validation data')
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# Print confusion matrix for training data
y_pred_train = model_m.predict(x_train)
# Take the class with the highest probability from the train predictions
max_y_pred_train = np.argmax(y_pred_train, axis=1)
print(classification_report(y_train, max_y_pred_train))
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001A5054BDDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 653/653 [==============================] - 2s 3ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.89      0.84      1864
#          1.0       0.98      0.97      0.97      6567
#          2.0       1.00      1.00      1.00      1050
#          3.0       1.00      1.00      1.00       833
#          4.0       0.78      0.90      0.84      2342
#          5.0       0.97      0.91      0.94      8212
#
#     accuracy                           0.93     20868
#    macro avg       0.92      0.94      0.93     20868
# weighted avg       0.94      0.93      0.94     20868

# %%
x_test, y_test = create_segments_and_labels(df_test,
                                              TIME_PERIODS,
                                              STEP_DISTANCE,
                                              LABEL)

# %%
print('x_test shape: ', x_test.shape)
print(x_test.shape[0], 'testing samples')
print('y_test shape: ', y_test.shape)
# Out:
# x_test shape:  (6584, 80, 3)
# 6584 testing samples
# y_test shape:  (6584,)

# %%
x_test = x_test.astype('float32')
y_test = y_test.astype('float32')

y_test_hot = np_utils.to_categorical(y_test, num_classes)
print('New y_test shape: ', y_test_hot.shape)
# Out:
# New y_test shape:  (6584, 6)

# %%
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap='coolwarm',
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_test = model_m.predict(x_test)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = np.argmax(y_test_hot, axis=1)

show_confusion_matrix(max_y_test, max_y_pred_test)

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 206/206 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       650
#            1       0.36      1.00      0.53      1990
#            2       1.00      0.11      0.20       452
#            3       0.00      0.00      0.00       370
#            4       0.20      0.00      0.01       725
#            5       0.04      0.02      0.02      2397
#
#     accuracy                           0.32      6584
#    macro avg       0.27      0.19      0.13      6584
# weighted avg       0.22      0.32      0.18      6584
# C:\Users\sjkan\anaconda3\envs\downgrade\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sjkan\anaconda3\envs\downgrade\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sjkan\anaconda3\envs\downgrade\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
